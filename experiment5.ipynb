# %%
#get 3rd element from first and 3rd element from last of a tuple
tuples=(1,2,3,4,5,6)
print("3rd element from the first is",tuples[2],"and 3rd element from the last is",tuples[-3])
# Out:
# 3rd element from the first is 3 and 3rd element from the last is 4

# %%
#generate a tuple with numbers and find the average of all items
n=input("Enter the numbers:")
tuples=tuple(map(int,n.split(",")))
print("Tuple is:",tuples)
print("Average is:",sum(tuples)/len(tuples))
# Out:
# Enter the numbers: 1,2,3,4,5,6,7,8
# Tuple is: (1, 2, 3, 4, 5, 6, 7, 8)
# Average is: 4.5
