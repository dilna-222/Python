# %%
#DIsplay first and last colors
color=input("Enter the colors:")
C=color.split(",")
print("First color:", C[0])
print("Second color:",C[-1])
# Out:
# Enter the colors: BLUE,GREEN,YELLOW
# First color: BLUE
# Second color: YELLOW

# %%
#file extension
filename=input("Enter the filename:")
extension=filename.split(".")[-1]
print("Extension:",extension)
# Out:
# Enter the filename: program1.c
# Extension: c

# %%
#list the numbers and find the sum
numbers=input("Enter the numbers:")
lists=list(map(int,number.split(",")))
print("List is:",lists)
print("Sum is:",sum(lists))
# Out:
# Enter the numbers: 1,2,3,4,5
# List is: [1, 2, 3, 4, 5]
# Sum is: 15
